# %%
import pandas
data = pandas.read_csv("C:\\Users\\Admin\\Documents\\BreastCancerData.csv")

# %%
data.columns = ["ID","Result","Mean_Radius","Mean_Texture","Mean_Perimeter",
                   "Mean_Area","Mean_Smoothness","Mean_Compactness", "Mean_Concavity",
                   "Mean_ConcavePoints", "Mean_Symmetry","Mean_FractalDimension",
                   "SE_Radius","SE_Texture","SE_Perimeter","SE_Area","SE_Smoothness",
                   "SE_Compactness","SE_Concavity","SE_ConcavePoints","SE_Symmetry",
                   "SE_FractalDimension","Worst_Radius","Worst_Texture","Worst_Perimeter",
                   "Worst_Area","Worst_Smoothness","Worst_Compactness","Worst_Concavity",
                   "Worst_ConcavePoints","Worst_Symmetry","Worst_FractalDimension"]

# %%
data
# Out:
#            ID Result  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0      842517      M       20.570         17.77          132.90     1326.0
# 1    84300903      M       19.690         21.25          130.00     1203.0
# 2    84348301      M       11.420         20.38           77.58      386.1
# 3    84358402      M       20.290         14.34          135.10     1297.0
# 4      843786      M       12.450         15.70           82.57      477.1
# 5      844359      M       18.250         19.98          119.60     1040.0
# 6    84458202      M       13.710         20.83           90.20      577.9
# 7      844981      M       13.000         21.82           87.50      519.8
# 8    84501001      M       12.460         24.04           83.97      475.9
# 9      845636      M       16.020         23.24          102.70      797.8
# 10   84610002      M       15.780         17.89          103.60      781.0
# ...

# %%
data.drop(columns=["ID"])
# Out:
#     Result  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0        M       20.570         17.77          132.90     1326.0
# 1        M       19.690         21.25          130.00     1203.0
# 2        M       11.420         20.38           77.58      386.1
# 3        M       20.290         14.34          135.10     1297.0
# 4        M       12.450         15.70           82.57      477.1
# 5        M       18.250         19.98          119.60     1040.0
# 6        M       13.710         20.83           90.20      577.9
# 7        M       13.000         21.82           87.50      519.8
# 8        M       12.460         24.04           83.97      475.9
# 9        M       16.020         23.24          102.70      797.8
# 10       M       15.780         17.89          103.60      781.0
# 11       M       19.170         24.80          132.40     1123.0
# 12       M       15.850         23.95          103.70      782.7
# ...

# %%
data.drop(columns=['Result'])
# Out:
#            ID  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0      842517       20.570         17.77          132.90     1326.0
# 1    84300903       19.690         21.25          130.00     1203.0
# 2    84348301       11.420         20.38           77.58      386.1
# 3    84358402       20.290         14.34          135.10     1297.0
# 4      843786       12.450         15.70           82.57      477.1
# 5      844359       18.250         19.98          119.60     1040.0
# 6    84458202       13.710         20.83           90.20      577.9
# 7      844981       13.000         21.82           87.50      519.8
# 8    84501001       12.460         24.04           83.97      475.9
# 9      845636       16.020         23.24          102.70      797.8
# 10   84610002       15.780         17.89          103.60      781.0
# 11     846226       19.170         24.80          132.40     1123.0
# 12     846381       15.850         23.95          103.70      782.7
# ...

# %%
data
# Out:
#            ID Result  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0      842517      M       20.570         17.77          132.90     1326.0
# 1    84300903      M       19.690         21.25          130.00     1203.0
# 2    84348301      M       11.420         20.38           77.58      386.1
# 3    84358402      M       20.290         14.34          135.10     1297.0
# 4      843786      M       12.450         15.70           82.57      477.1
# 5      844359      M       18.250         19.98          119.60     1040.0
# 6    84458202      M       13.710         20.83           90.20      577.9
# 7      844981      M       13.000         21.82           87.50      519.8
# 8    84501001      M       12.460         24.04           83.97      475.9
# 9      845636      M       16.020         23.24          102.70      797.8
# 10   84610002      M       15.780         17.89          103.60      781.0
# ...

# %%
data.drop(['ID'], axis=1)
# Out:
#     Result  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0        M       20.570         17.77          132.90     1326.0
# 1        M       19.690         21.25          130.00     1203.0
# 2        M       11.420         20.38           77.58      386.1
# 3        M       20.290         14.34          135.10     1297.0
# 4        M       12.450         15.70           82.57      477.1
# 5        M       18.250         19.98          119.60     1040.0
# 6        M       13.710         20.83           90.20      577.9
# 7        M       13.000         21.82           87.50      519.8
# 8        M       12.460         24.04           83.97      475.9
# 9        M       16.020         23.24          102.70      797.8
# 10       M       15.780         17.89          103.60      781.0
# 11       M       19.170         24.80          132.40     1123.0
# 12       M       15.850         23.95          103.70      782.7
# ...

# %%
data.drop(['Result'], axis=1)
# Out:
#            ID  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0      842517       20.570         17.77          132.90     1326.0
# 1    84300903       19.690         21.25          130.00     1203.0
# 2    84348301       11.420         20.38           77.58      386.1
# 3    84358402       20.290         14.34          135.10     1297.0
# 4      843786       12.450         15.70           82.57      477.1
# 5      844359       18.250         19.98          119.60     1040.0
# 6    84458202       13.710         20.83           90.20      577.9
# 7      844981       13.000         21.82           87.50      519.8
# 8    84501001       12.460         24.04           83.97      475.9
# 9      845636       16.020         23.24          102.70      797.8
# 10   84610002       15.780         17.89          103.60      781.0
# 11     846226       19.170         24.80          132.40     1123.0
# 12     846381       15.850         23.95          103.70      782.7
# ...

# %%
data.drop(['ID'], axis=1)
# Out:
#     Result  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0        M       20.570         17.77          132.90     1326.0
# 1        M       19.690         21.25          130.00     1203.0
# 2        M       11.420         20.38           77.58      386.1
# 3        M       20.290         14.34          135.10     1297.0
# 4        M       12.450         15.70           82.57      477.1
# 5        M       18.250         19.98          119.60     1040.0
# 6        M       13.710         20.83           90.20      577.9
# 7        M       13.000         21.82           87.50      519.8
# 8        M       12.460         24.04           83.97      475.9
# 9        M       16.020         23.24          102.70      797.8
# 10       M       15.780         17.89          103.60      781.0
# 11       M       19.170         24.80          132.40     1123.0
# 12       M       15.850         23.95          103.70      782.7
# ...

# %%
data.drop(['Result'], axis=1)
# Out:
#            ID  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0      842517       20.570         17.77          132.90     1326.0
# 1    84300903       19.690         21.25          130.00     1203.0
# 2    84348301       11.420         20.38           77.58      386.1
# 3    84358402       20.290         14.34          135.10     1297.0
# 4      843786       12.450         15.70           82.57      477.1
# 5      844359       18.250         19.98          119.60     1040.0
# 6    84458202       13.710         20.83           90.20      577.9
# 7      844981       13.000         21.82           87.50      519.8
# 8    84501001       12.460         24.04           83.97      475.9
# 9      845636       16.020         23.24          102.70      797.8
# 10   84610002       15.780         17.89          103.60      781.0
# 11     846226       19.170         24.80          132.40     1123.0
# 12     846381       15.850         23.95          103.70      782.7
# ...

# %%
data = data.drop(['ID'], axis=1)

# %%
data = data.drop(['Result'], axis=1)

# %%
data
# Out:
#      Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  Mean_Smoothness  \
# 0         20.570         17.77          132.90     1326.0          0.08474
# 1         19.690         21.25          130.00     1203.0          0.10960
# 2         11.420         20.38           77.58      386.1          0.14250
# 3         20.290         14.34          135.10     1297.0          0.10030
# 4         12.450         15.70           82.57      477.1          0.12780
# 5         18.250         19.98          119.60     1040.0          0.09463
# 6         13.710         20.83           90.20      577.9          0.11890
# 7         13.000         21.82           87.50      519.8          0.12730
# 8         12.460         24.04           83.97      475.9          0.11860
# 9         16.020         23.24          102.70      797.8          0.08206
# 10        15.780         17.89          103.60      781.0          0.09710
# ...

# %%
FeatureScaling <- lambda(data): 
    ((data - min(data)) / (max(data) - min(data)))
# Out:
#   File "<ipython-input-29-c7f9eaf05ca6>", line 1
#     FeatureScaling <- lambda(data):
#                            ^
# SyntaxError: invalid syntax

# %%
import sklearn

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(data)

# %%
data
# Out:
#      Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  Mean_Smoothness  \
# 0         20.570         17.77          132.90     1326.0          0.08474
# 1         19.690         21.25          130.00     1203.0          0.10960
# 2         11.420         20.38           77.58      386.1          0.14250
# 3         20.290         14.34          135.10     1297.0          0.10030
# 4         12.450         15.70           82.57      477.1          0.12780
# 5         18.250         19.98          119.60     1040.0          0.09463
# 6         13.710         20.83           90.20      577.9          0.11890
# 7         13.000         21.82           87.50      519.8          0.12730
# 8         12.460         24.04           83.97      475.9          0.11860
# 9         16.020         23.24          102.70      797.8          0.08206
# 10        15.780         17.89          103.60      781.0          0.09710
# ...

# %%
scaled_data
# Out:
# array([[ 1.83208378, -0.35832707,  1.68910604, ...,  1.09526221,
#         -0.24044363,  0.28529387],
#        [ 1.58210603,  0.45385958,  1.56958968, ...,  1.96646779,
#          1.16385786,  0.2053006 ],
#        [-0.76711673,  0.25081292, -0.59077158, ...,  2.18809026,
#          6.08623563,  4.95045676],
#        ...,
#        [ 0.70434323,  2.04789258,  0.6752776 , ...,  0.41969578,
#         -1.10613122, -0.31576665],
#        [ 1.84060575,  2.33962629,  1.98583632, ...,  2.30272257,
#          1.93516598,  2.22846365],
#        [-1.80679694,  1.22170271, -1.81313547, ..., -1.74761915,
#         -0.04354852, -0.74961903]])

# %%
dataframe = pandas.DataFrame(scaled_data)

# %%
dataframe
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.832084 -0.358327  1.689106  1.910392 -0.825266 -0.485498 -0.019278
# 1    1.582106  0.453860  1.569590  1.560576  0.946192  1.067960  1.375494
# 2   -0.767117  0.250813 -0.590772 -0.762711  3.290559  3.438483  1.930879
# 3    1.752545 -1.158844  1.779774  1.827915  0.283499  0.549886  1.383068
# 4   -0.474529 -0.841438 -0.385121 -0.503904  2.243076  1.261043  0.875648
# 5    1.173052  0.157458  1.140979  1.097000 -0.120530  0.094898  0.306379
# 6   -0.116606  0.355837 -0.070669 -0.217226  1.608886  1.155899  0.066049
# 7   -0.318293  0.586890 -0.181943 -0.382464  2.207448  1.704560  1.230337
# 8   -0.471688  1.105009 -0.327423 -0.507317  1.587509  2.591595  1.752903
# 9    0.539585  0.918300  0.444487  0.408176 -1.016235 -0.713947 -0.699751
# 10   0.471409 -0.330321  0.481579  0.360396  0.055475  0.481064  0.140269
# 11   1.434392  1.282383  1.668500  1.333054  0.076853  2.710121  1.490358
# ...

# %%
dataframe = dataframe.drop(0)

# %%
dataframe
# Out:
#            0         1         2         3         4         5         6   \
# 1    1.582106  0.453860  1.569590  1.560576  0.946192  1.067960  1.375494
# 2   -0.767117  0.250813 -0.590772 -0.762711  3.290559  3.438483  1.930879
# 3    1.752545 -1.158844  1.779774  1.827915  0.283499  0.549886  1.383068
# 4   -0.474529 -0.841438 -0.385121 -0.503904  2.243076  1.261043  0.875648
# 5    1.173052  0.157458  1.140979  1.097000 -0.120530  0.094898  0.306379
# 6   -0.116606  0.355837 -0.070669 -0.217226  1.608886  1.155899  0.066049
# 7   -0.318293  0.586890 -0.181943 -0.382464  2.207448  1.704560  1.230337
# 8   -0.471688  1.105009 -0.327423 -0.507317  1.587509  2.591595  1.752903
# 9    0.539585  0.918300  0.444487  0.408176 -1.016235 -0.713947 -0.699751
# 10   0.471409 -0.330321  0.481579  0.360396  0.055475  0.481064  0.140269
# 11   1.434392  1.282383  1.668500  1.333054  0.076853  2.710121  1.490358
# 12   0.491294  1.084004  0.485700  0.365231 -0.877283 -0.073332  0.138249
# ...

# %%
dataframe = pandas.DataFrame(scaled_data)

# %%
dataframe
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.832084 -0.358327  1.689106  1.910392 -0.825266 -0.485498 -0.019278
# 1    1.582106  0.453860  1.569590  1.560576  0.946192  1.067960  1.375494
# 2   -0.767117  0.250813 -0.590772 -0.762711  3.290559  3.438483  1.930879
# 3    1.752545 -1.158844  1.779774  1.827915  0.283499  0.549886  1.383068
# 4   -0.474529 -0.841438 -0.385121 -0.503904  2.243076  1.261043  0.875648
# 5    1.173052  0.157458  1.140979  1.097000 -0.120530  0.094898  0.306379
# 6   -0.116606  0.355837 -0.070669 -0.217226  1.608886  1.155899  0.066049
# 7   -0.318293  0.586890 -0.181943 -0.382464  2.207448  1.704560  1.230337
# 8   -0.471688  1.105009 -0.327423 -0.507317  1.587509  2.591595  1.752903
# 9    0.539585  0.918300  0.444487  0.408176 -1.016235 -0.713947 -0.699751
# 10   0.471409 -0.330321  0.481579  0.360396  0.055475  0.481064  0.140269
# 11   1.434392  1.282383  1.668500  1.333054  0.076853  2.710121  1.490358
# ...

# %%
dataframe.columns = ["Mean_Radius","Mean_Texture","Mean_Perimeter",
                   "Mean_Area","Mean_Smoothness","Mean_Compactness", "Mean_Concavity",
                   "Mean_ConcavePoints", "Mean_Symmetry","Mean_FractalDimension",
                   "SE_Radius","SE_Texture","SE_Perimeter","SE_Area","SE_Smoothness",
                   "SE_Compactness","SE_Concavity","SE_ConcavePoints","SE_Symmetry",
                   "SE_FractalDimension","Worst_Radius","Worst_Texture","Worst_Perimeter",
                   "Worst_Area","Worst_Smoothness","Worst_Compactness","Worst_Concavity",
                   "Worst_ConcavePoints","Worst_Symmetry","Worst_FractalDimension"]

# %%
dataframe
# Out:
#      Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  Mean_Smoothness  \
# 0       1.832084     -0.358327        1.689106   1.910392        -0.825266
# 1       1.582106      0.453860        1.569590   1.560576         0.946192
# 2      -0.767117      0.250813       -0.590772  -0.762711         3.290559
# 3       1.752545     -1.158844        1.779774   1.827915         0.283499
# 4      -0.474529     -0.841438       -0.385121  -0.503904         2.243076
# 5       1.173052      0.157458        1.140979   1.097000        -0.120530
# 6      -0.116606      0.355837       -0.070669  -0.217226         1.608886
# 7      -0.318293      0.586890       -0.181943  -0.382464         2.207448
# 8      -0.471688      1.105009       -0.327423  -0.507317         1.587509
# 9       0.539585      0.918300        0.444487   0.408176        -1.016235
# 10      0.471409     -0.330321        0.481579   0.360396         0.055475
# ...

# %%
import numpy as np

# %%
from sklearn import preprocessing

# %%
minmax = preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
minmax.fit(scaled_data).transform(scaled_data)
# Out:
# array([[0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        [0.2100904 , 0.36083869, 0.23350149, ..., 0.88487973, 1.        ,
#         0.77371114],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
minmax.fit(data).transform(data)
# Out:
# array([[0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        [0.2100904 , 0.36083869, 0.23350149, ..., 0.88487973, 1.        ,
#         0.77371114],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
preprocessing.Normalizer().fit(data).transform(data)
# Out:
# array([[8.66575595e-03, 7.48616836e-03, 5.59882822e-02, ...,
#         7.83583182e-05, 1.15852352e-04, 3.75024596e-05],
#        [9.36668268e-03, 1.01087865e-02, 6.18419883e-02, ...,
#         1.15596947e-04, 1.71873157e-04, 4.16624718e-05],
#        [1.63246545e-02, 2.91327898e-02, 1.10899010e-01, ...,
#         3.68090940e-04, 9.48888413e-04, 2.47299933e-04],
#        ...,
#        [1.16438847e-02, 1.96964025e-02, 7.59658259e-02, ...,
#         9.94640269e-05, 1.55579134e-04, 5.48525170e-05],
#        [9.23020523e-03, 1.31418408e-02, 6.27743569e-02, ...,
#         1.18738077e-04, 1.83125480e-04, 5.55604587e-05],
#        [2.31098880e-02, 7.30820427e-02, 1.42709515e-01, ...,
#         0.00000000e+00, 8.55006294e-04, 2.09626935e-04]])

# %%
preprocessing.Normalizer().fit(data).transform(scaled_data)
# Out:
# array([[ 0.35596681, -0.06962157,  0.32818679, ...,  0.21280522,
#         -0.04671727,  0.0554315 ],
#        [ 0.25715164,  0.07376923,  0.25511726, ...,  0.31962486,
#          0.18917061,  0.03336906],
#        [-0.05461405,  0.01785636, -0.04205935, ...,  0.15577872,
#          0.43330298,  0.35244243],
#        ...,
#        [ 0.18177307,  0.52850899,  0.17427197, ...,  0.10831281,
#         -0.28546434, -0.08149134],
#        [ 0.16517814,  0.20996084,  0.17821131, ...,  0.20664906,
#          0.17366409,  0.19998497],
#        [-0.26091055,  0.17642001, -0.26182587, ..., -0.25236498,
#         -0.00628862, -0.10824875]])

# %%
norm = preprocessing.Normalizer().fit(data).transform(scaled_data)

# %%
df = pandas.DataFrame(norm)

# %%
df
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.355967 -0.069622  0.328187  0.371182 -0.160346 -0.094330 -0.003746
# 1    0.257152  0.073769  0.255117  0.253652  0.153792  0.173584  0.223569
# 2   -0.054614  0.017856 -0.042059 -0.054300  0.234268  0.244799  0.137467
# 3    0.297468 -0.196696  0.302090  0.310261  0.048120  0.093335  0.234755
# 4   -0.082315 -0.145962 -0.066806 -0.087411  0.389101  0.218750  0.151897
# 5    0.294399  0.039517  0.286350  0.275312 -0.030249  0.023816  0.076891
# 6   -0.027644  0.084357 -0.016753 -0.051497  0.381413  0.274025  0.015658
# 7   -0.052592  0.096972 -0.030062 -0.063195  0.364737  0.281644  0.203289
# 8   -0.038627  0.090489 -0.026813 -0.041544  0.130001  0.212226  0.143545
# 9    0.151464  0.257771  0.124770  0.114577 -0.285262 -0.200408 -0.196423
# 10   0.127331 -0.089222  0.130077  0.097345  0.014984  0.129938  0.037887
# 11   0.121938  0.109015  0.141839  0.113323  0.006533  0.230387  0.126695
# ...

# %%
df.columns = ["Mean_Radius","Mean_Texture","Mean_Perimeter",
                   "Mean_Area","Mean_Smoothness","Mean_Compactness", "Mean_Concavity",
                   "Mean_ConcavePoints", "Mean_Symmetry","Mean_FractalDimension",
                   "SE_Radius","SE_Texture","SE_Perimeter","SE_Area","SE_Smoothness",
                   "SE_Compactness","SE_Concavity","SE_ConcavePoints","SE_Symmetry",
                   "SE_FractalDimension","Worst_Radius","Worst_Texture","Worst_Perimeter",
                   "Worst_Area","Worst_Smoothness","Worst_Compactness","Worst_Concavity",
                   "Worst_ConcavePoints","Worst_Symmetry","Worst_FractalDimension"]

# %%
df
# Out:
#      Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  Mean_Smoothness  \
# 0       0.355967     -0.069622        0.328187   0.371182        -0.160346
# 1       0.257152      0.073769        0.255117   0.253652         0.153792
# 2      -0.054614      0.017856       -0.042059  -0.054300         0.234268
# 3       0.297468     -0.196696        0.302090   0.310261         0.048120
# 4      -0.082315     -0.145962       -0.066806  -0.087411         0.389101
# 5       0.294399      0.039517        0.286350   0.275312        -0.030249
# 6      -0.027644      0.084357       -0.016753  -0.051497         0.381413
# 7      -0.052592      0.096972       -0.030062  -0.063195         0.364737
# 8      -0.038627      0.090489       -0.026813  -0.041544         0.130001
# 9       0.151464      0.257771        0.124770   0.114577        -0.285262
# 10      0.127331     -0.089222        0.130077   0.097345         0.014984
# ...

# %%
norm = preprocessing.Normalizer().fit(scaled_data).transform(scaled_data)

# %%
norm
# Out:
# array([[ 0.35596681, -0.06962157,  0.32818679, ...,  0.21280522,
#         -0.04671727,  0.0554315 ],
#        [ 0.25715164,  0.07376923,  0.25511726, ...,  0.31962486,
#          0.18917061,  0.03336906],
#        [-0.05461405,  0.01785636, -0.04205935, ...,  0.15577872,
#          0.43330298,  0.35244243],
#        ...,
#        [ 0.18177307,  0.52850899,  0.17427197, ...,  0.10831281,
#         -0.28546434, -0.08149134],
#        [ 0.16517814,  0.20996084,  0.17821131, ...,  0.20664906,
#          0.17366409,  0.19998497],
#        [-0.26091055,  0.17642001, -0.26182587, ..., -0.25236498,
#         -0.00628862, -0.10824875]])

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
scaled_data
# Out:
# array([[ 1.83208378, -0.35832707,  1.68910604, ...,  1.09526221,
#         -0.24044363,  0.28529387],
#        [ 1.58210603,  0.45385958,  1.56958968, ...,  1.96646779,
#          1.16385786,  0.2053006 ],
#        [-0.76711673,  0.25081292, -0.59077158, ...,  2.18809026,
#          6.08623563,  4.95045676],
#        ...,
#        [ 0.70434323,  2.04789258,  0.6752776 , ...,  0.41969578,
#         -1.10613122, -0.31576665],
#        [ 1.84060575,  2.33962629,  1.98583632, ...,  2.30272257,
#          1.93516598,  2.22846365],
#        [-1.80679694,  1.22170271, -1.81313547, ..., -1.74761915,
#         -0.04354852, -0.74961903]])

# %%
print(scaler.fit(data))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
print(scaler.fit(data))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
print(scaler.data_max_)
# Out:
# [2.811e+01 3.928e+01 1.885e+02 2.501e+03 1.634e-01 3.454e-01 4.268e-01
#  2.012e-01 3.040e-01 9.744e-02 2.873e+00 4.885e+00 2.198e+01 5.422e+02
#  3.113e-02 1.354e-01 3.960e-01 5.279e-02 7.895e-02 2.984e-02 3.604e+01
#  4.954e+01 2.512e+02 4.254e+03 2.226e-01 1.058e+00 1.252e+00 2.910e-01
#  6.638e-01 2.075e-01]

# %%
print(scaler.data_min_)
# Out:
# [6.981e+00 9.710e+00 4.379e+01 1.435e+02 5.263e-02 1.938e-02 0.000e+00
#  0.000e+00 1.060e-01 4.996e-02 1.115e-01 3.602e-01 7.570e-01 6.802e+00
#  1.713e-03 2.252e-03 0.000e+00 0.000e+00 7.882e-03 8.948e-04 7.930e+00
#  1.202e+01 5.041e+01 1.852e+02 7.117e-02 2.729e-02 0.000e+00 0.000e+00
#  1.565e-01 5.504e-02]

# %%
scaler
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
print(scaler.transform(data))
# Out:
# [[0.64314449 0.27257355 0.61578329 ... 0.63917526 0.23358959 0.22287813]
#  [0.60149557 0.3902604  0.59574321 ... 0.83505155 0.40370589 0.21343303]
#  [0.2100904  0.36083869 0.23350149 ... 0.88487973 1.         0.77371114]
#  ...
#  [0.45525108 0.62123774 0.44578813 ... 0.48728522 0.12872068 0.1519087 ]
#  [0.64456434 0.66351031 0.66553797 ... 0.91065292 0.49714173 0.45231536]
#  [0.03686876 0.50152181 0.02853984 ... 0.         0.25744136 0.10068215]]

# %%
norm_form = scaler.transform(data)

# %%
norm_form
# Out:
# array([[0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        [0.2100904 , 0.36083869, 0.23350149, ..., 0.88487973, 1.        ,
#         0.77371114],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
normDf = pandas.DataFrame(norm_form)

# %%
normDf
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.643144  0.272574  0.615783  0.501591  0.289880  0.181768  0.203608
# 1    0.601496  0.390260  0.595743  0.449417  0.514309  0.431017  0.462512
# 2    0.210090  0.360839  0.233501  0.102906  0.811321  0.811361  0.565604
# 3    0.629893  0.156578  0.630986  0.489290  0.430351  0.347893  0.463918
# 4    0.258839  0.202570  0.267984  0.141506  0.678613  0.461996  0.369728
# 5    0.533343  0.347311  0.523875  0.380276  0.379164  0.274891  0.264058
# 6    0.318472  0.376057  0.320710  0.184263  0.598267  0.445126  0.219447
# 7    0.284869  0.409537  0.302052  0.159618  0.674099  0.533157  0.435567
# 8    0.259312  0.484613  0.277659  0.140997  0.595558  0.675480  0.532568
# 9    0.427801  0.457558  0.407090  0.277540  0.265686  0.145114  0.077296
# 10   0.416442  0.276632  0.413309  0.270414  0.401462  0.336850  0.233224
# 11   0.576885  0.510315  0.612328  0.415483  0.404171  0.694497  0.483833
# ...

# %%
normDf.columns = ["Mean_Radius","Mean_Texture","Mean_Perimeter",
                   "Mean_Area","Mean_Smoothness","Mean_Compactness", "Mean_Concavity",
                   "Mean_ConcavePoints", "Mean_Symmetry","Mean_FractalDimension",
                   "SE_Radius","SE_Texture","SE_Perimeter","SE_Area","SE_Smoothness",
                   "SE_Compactness","SE_Concavity","SE_ConcavePoints","SE_Symmetry",
                   "SE_FractalDimension","Worst_Radius","Worst_Texture","Worst_Perimeter",
                   "Worst_Area","Worst_Smoothness","Worst_Compactness","Worst_Concavity",
                   "Worst_ConcavePoints","Worst_Symmetry","Worst_FractalDimension"]

# %%
normDf
# Out:
#      Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  Mean_Smoothness  \
# 0       0.643144      0.272574        0.615783   0.501591         0.289880
# 1       0.601496      0.390260        0.595743   0.449417         0.514309
# 2       0.210090      0.360839        0.233501   0.102906         0.811321
# 3       0.629893      0.156578        0.630986   0.489290         0.430351
# 4       0.258839      0.202570        0.267984   0.141506         0.678613
# 5       0.533343      0.347311        0.523875   0.380276         0.379164
# 6       0.318472      0.376057        0.320710   0.184263         0.598267
# 7       0.284869      0.409537        0.302052   0.159618         0.674099
# 8       0.259312      0.484613        0.277659   0.140997         0.595558
# 9       0.427801      0.457558        0.407090   0.277540         0.265686
# 10      0.416442      0.276632        0.413309   0.270414         0.401462
# ...

# %%
BCD_Training <- normDf[1:450,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-c207903fff09> in <module>()
# ----> 1 BCD_Training <- normDf[1:450,]
#
# NameError: name 'BCD_Training' is not defined

# %%
BCD_Training
# Out:
# array([[0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        [0.2100904 , 0.36083869, 0.23350149, ..., 0.88487973, 1.        ,
#         0.77371114],
#        [0.62989256, 0.15657761, 0.63098611, ..., 0.55841924, 0.15750049,
#         0.14259478],
#        ...,
#        [0.35728146, 0.32566791, 0.34869739, ..., 0.32969072, 0.17859255,
#         0.12849272],
#        [0.6682285 , 0.36557322, 0.65171723, ..., 0.78350515, 0.13857678,
#         0.12600026],
#        [0.23138814, 0.40006764, 0.22831871, ..., 0.30068729, 0.14587029,
#         0.29174866]])

# %%
BCD_Test = normDf.values[451:569,]

# %%
BCD_Test
# Out:
# array([[0.23754082, 0.62631045, 0.22790408, ..., 0.24453608, 0.17386162,
#         0.17643972],
#        [0.35728146, 0.14440311, 0.34600235, ..., 0.36735395, 0.20520402,
#         0.15125279],
#        [0.26688438, 0.25160636, 0.25450902, ..., 0.33852234, 0.33609304,
#         0.11976912],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
# Out:
#   File "<ipython-input-90-1beaf570f154>", line 1
#     K_Value = floor(sqrt(length(BCD_Training[,1])))
#                                              ^
# SyntaxError: invalid syntax

# %%
import math

# %%
BCD_Training_length = len(BCD_Training.values[:,1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-c5e2b4102074> in <module>()
# ----> 1 BCD_Training_length = len(BCD_Training.values[:,1])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
K_Value = math.floor(math.sqrt(len(BCD_Training)))

# %%
K_Value
# Out:
# 21

# %%
original_data = pandas.read_csv("C:\\Users\\Admin\\Documents\\BreastCancerData.csv")

# %%
original_data.columns = ["ID","Result","Mean_Radius","Mean_Texture","Mean_Perimeter",
                   "Mean_Area","Mean_Smoothness","Mean_Compactness", "Mean_Concavity",
                   "Mean_ConcavePoints", "Mean_Symmetry","Mean_FractalDimension",
                   "SE_Radius","SE_Texture","SE_Perimeter","SE_Area","SE_Smoothness",
                   "SE_Compactness","SE_Concavity","SE_ConcavePoints","SE_Symmetry",
                   "SE_FractalDimension","Worst_Radius","Worst_Texture","Worst_Perimeter",
                   "Worst_Area","Worst_Smoothness","Worst_Compactness","Worst_Concavity",
                   "Worst_ConcavePoints","Worst_Symmetry","Worst_FractalDimension"]

# %%
original_data
# Out:
#            ID Result  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0      842517      M       20.570         17.77          132.90     1326.0
# 1    84300903      M       19.690         21.25          130.00     1203.0
# 2    84348301      M       11.420         20.38           77.58      386.1
# 3    84358402      M       20.290         14.34          135.10     1297.0
# 4      843786      M       12.450         15.70           82.57      477.1
# 5      844359      M       18.250         19.98          119.60     1040.0
# 6    84458202      M       13.710         20.83           90.20      577.9
# 7      844981      M       13.000         21.82           87.50      519.8
# 8    84501001      M       12.460         24.04           83.97      475.9
# 9      845636      M       16.020         23.24          102.70      797.8
# 10   84610002      M       15.780         17.89          103.60      781.0
# ...

# %%
BCD_NoID = original_data[columns='ID']
# Out:
#   File "<ipython-input-110-158fb6fe2204>", line 1
#     BCD_NoID = original_data[columns='ID']
#                                     ^
# SyntaxError: invalid syntax

# %%
BCD_NoID = original_data['ID']

# %%
BCD_NoID
# Out:
# 0        842517
# 1      84300903
# 2      84348301
# 3      84358402
# 4        843786
# 5        844359
# 6      84458202
# 7        844981
# 8      84501001
# 9        845636
# 10     84610002
# 11       846226
# 12       846381
# 13     84667401
# 14     84799002
# 15       848406
# 16     84862001
# 17       849014
# 18      8510426
# 19      8510653
# 20      8510824
# 21      8511133
# 22       851509
# 23       852552
# 24       852631
# 25       852763
# 26       852781
# 27       852973
# 28       853201
# 29       853401
#          ...
# 538      921362
# 539      921385
# 540      921386
# 541      921644
# 542      922296
# 543      922297
# 544      922576
# 545      922577
# 546      922840
# 547      923169
# 548      923465
# 549      923748
# 550      923780
# 551      924084
# 552      924342
# 553      924632
# 554      924934
# 555      924964
# 556      925236
# 557      925277
# 558      925291
# 559      925292
# 560      925311
# 561      925622
# ...

# %%
BCD_NoID = BCD_NoID.drop(0)

# %%
BCD_NoID
# Out:
# 1      84300903
# 2      84348301
# 3      84358402
# 4        843786
# 5        844359
# 6      84458202
# 7        844981
# 8      84501001
# 9        845636
# 10     84610002
# 11       846226
# 12       846381
# 13     84667401
# 14     84799002
# 15       848406
# 16     84862001
# 17       849014
# 18      8510426
# 19      8510653
# 20      8510824
# 21      8511133
# 22       851509
# 23       852552
# 24       852631
# 25       852763
# 26       852781
# 27       852973
# 28       853201
# 29       853401
# 30       853612
#          ...
# 538      921362
# 539      921385
# 540      921386
# 541      921644
# 542      922296
# 543      922297
# 544      922576
# 545      922577
# 546      922840
# 547      923169
# 548      923465
# 549      923748
# 550      923780
# 551      924084
# 552      924342
# 553      924632
# 554      924934
# 555      924964
# 556      925236
# 557      925277
# 558      925291
# 559      925292
# 560      925311
# 561      925622
# ...

# %%
BCD_NoID = original_data['ID']

# %%
BCD_NoID
# Out:
# 0        842517
# 1      84300903
# 2      84348301
# 3      84358402
# 4        843786
# 5        844359
# 6      84458202
# 7        844981
# 8      84501001
# 9        845636
# 10     84610002
# 11       846226
# 12       846381
# 13     84667401
# 14     84799002
# 15       848406
# 16     84862001
# 17       849014
# 18      8510426
# 19      8510653
# 20      8510824
# 21      8511133
# 22       851509
# 23       852552
# 24       852631
# 25       852763
# 26       852781
# 27       852973
# 28       853201
# 29       853401
#          ...
# 538      921362
# 539      921385
# 540      921386
# 541      921644
# 542      922296
# 543      922297
# 544      922576
# 545      922577
# 546      922840
# 547      923169
# 548      923465
# 549      923748
# 550      923780
# 551      924084
# 552      924342
# 553      924632
# 554      924934
# 555      924964
# 556      925236
# 557      925277
# 558      925291
# 559      925292
# 560      925311
# 561      925622
# ...

# %%
BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-710a88eb449b> in <module>()
# ----> 1 BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
#
# NameError: name 'knn' is not defined

# %%
import KNN
BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
# Out:
# Traceback (most recent call last):
#
#   File "c:\users\admin\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-119-7cc01a42e1cc>", line 1, in <module>
#     import KNN
#
#   File "c:\users\admin\miniconda3\lib\site-packages\KNN.py", line 24
#     print(sortedDistIndicies[i])
#                                 ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-710a88eb449b> in <module>()
# ----> 1 BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
#
# NameError: name 'knn' is not defined

# %%
import knn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-123-f9cd853b073e> in <module>()
# ----> 1 import knn
#
# ModuleNotFoundError: No module named 'knn'

# %%
BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-710a88eb449b> in <module>()
# ----> 1 BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
#
# NameError: name 'knn' is not defined

# %%
knn = KNeighborsClassifier(n_neighbors=k_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-044d7bc3b34c> in <module>()
# ----> 1 knn = KNeighborsClassifier(n_neighbors=k_value)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
import from sklearn.neighbors.KNeighborsClassifier
# Out:
#   File "<ipython-input-127-3837318774e6>", line 1
#     import from sklearn.neighbors.KNeighborsClassifier
#               ^
# SyntaxError: invalid syntax

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=K_Value)

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=21, p=2,
#            weights='uniform')

# %%
BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-710a88eb449b> in <module>()
# ----> 1 BCD_Predictions = knn(BCD_Training,BCD_Test,BCD_NoID[1:450,1], k=K_Value)
#
# c:\users\admin\miniconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     808             key = check_bool_indexer(self.index, key)
#     809
# --> 810         return self._get_with(key)
#     811
#     812     def _get_with(self, key):
#
# c:\users\admin\miniconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     821             if isinstance(key, tuple):
#     822                 try:
# --> 823                     return self._get_values_tuple(key)
#     824                 except Exception:
#     825                     if len(key) == 1:
#
# c:\users\admin\miniconda3\lib\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#     866
# ...
